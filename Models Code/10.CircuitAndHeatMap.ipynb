# %% [markdown]
# #### Circuit and HeatMap

# %% [markdown]
# #### Circuit as shown in Figure 10

# %%
from qiskit import qpy
with open('circuit_3.qpy', 'rb') as handle:
    qc = qpy.load(handle)
 
qc[0].draw('mpl')

# %% [markdown]
# #### Circuit as shown in Figure 12

# %%
import pandas as pd

# Create the data dictionary
data = {
    "Modality": [
        "Text+Audio", "Text+Image", "Audio+Image",
        "Text+Audio", "Text+Image", "Audio+Image",
        "Text+Audio", "Text+Image", "Audio+Image",
        "Text+Audio", "Text+Image", "Audio+Image"
    ],
   # "Dimension": [8] * 12,
    "Model": [
        "VQC", "VQC", "VQC",
        "QCNN", "QCNN", "QCNN",
        "Random Forest", "Random Forest", "Random Forest",
        "CNN", "CNN", "CNN"
    ],
    "Accuracy": [
        72.38, 69.11, 68.87,
        73.36, 69.28, 64.29,
        68.72, 69.05, 68.72,
        74.75, 70.75, 67.89
    ],
    "Precision": [
        65.79, 67.10, 68.07,
        69.05, 68.07, 60.91,
        68.72, 69.05, 68.72,
        68.40, 68.40, 65.79
    ],
    "Recall": [
        45.19, 77.35, 67.83,
        67.39, 77.47, 62.26,
        70.06, 73.52, 71.14,
        69.87, 84.44, 69.85
    ],
    "F1 Score": [
        50.31, 51.57, 72.95,
        77.98, 54.08, 62.26,
        69.18, 62.89, 66.66,
        68.55, 47.77, 59.74
    ],
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#        Modality          Model  Accuracy  Precision  Recall  F1 Score
# 0    Text+Audio            VQC     72.38      65.79   45.19     50.31
# 1    Text+Image            VQC     69.11      67.10   77.35     51.57
# 2   Audio+Image            VQC     68.87      68.07   67.83     72.95
# 3    Text+Audio           QCNN     73.36      69.05   67.39     77.98
# 4    Text+Image           QCNN     69.28      68.07   77.47     54.08
# 5   Audio+Image           QCNN     64.29      60.91   62.26     62.26
# 6    Text+Audio  Random Forest     68.72      68.72   70.06     69.18
# 7    Text+Image  Random Forest     69.05      69.05   73.52     62.89
# 8   Audio+Image  Random Forest     68.72      68.72   71.14     66.66
# 9    Text+Audio            CNN     74.75      68.40   69.87     68.55
# 10   Text+Image            CNN     70.75      68.40   84.44     47.77
# 11  Audio+Image            CNN     67.89      65.79   69.85     59.74

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
heatmap_data = df_melted.pivot_table(index=["Modality", "Model"], columns="Metric", values="Value")
sns.heatmap(heatmap_data, annot=True, cmap="YlGnBu", fmt=".2f")

plt.title("Heatmap of Model Performance Metrics")
plt.show()
